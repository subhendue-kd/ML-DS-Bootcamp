# %% [markdown]
# <h1><center>Libraries And Utilities</center></h1>

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler, RobustScaler
from scipy import stats
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from yellowbrick.model_selection import FeatureImportances

# %%
df0 = pd.read_csv('dataset\plasma_processed.csv')
df0 = df0.drop('Unnamed: 0', axis=1)
df0.head()
# Out:
#    1_5-anhydroglucitol  1-monostearin  2_3-dihydroxybutanoic acid NIST  \
# 0                 9483            103                              101
# 1                27468            207                              155
# 2                13976             86                               78
# 3                19449            178                              104
# 4                17209            258                              103
#
#    2_4-diaminobutyric acid  2-deoxyerythritol  2-deoxytetronic acid  \
# 0                      963                389                   123
# 1                      335                227                   178
# 2                      176                152                    83
# 3                      467                270                   157
# 4                      979                314                   211
#
#    2-hydroxybutanoic acid  2-hydroxyglutaric acid  2-hydroxyhippuric acid  \
# 0                   20744                     139                      36
# 1                    8611                      78                      91
# 2                   22792                      92                      97
# 3                   29418                     123                      92
# 4                   16713                      76                      42
#
#    2-hydroxyvaleric acid  ...  tryptophan  tyrosine  UDP-glucuronic acid  \
# 0                    955  ...       27450     52403                   73
# 1                    103  ...       17898     37179                  157
# 2                   1010  ...       29503     30670                  211
# 3                    289  ...       16501     27573                   71
# 4                   1126  ...       24023     30096                  222
#
#      urea  uric acid  uridine  valine  xylitol  xylose    Class
# 0  255067      10057       63  157332      154    1380  disease
# 1  180080       8386      118  103083      324     929  disease
# 2  138861      15822      119   92045      253     610  disease
# 3  183633      14024      102   97349      223     746  disease
# 4  255081      23154       58  159671      189    2022  disease
#
# [5 rows x 159 columns]

# %%
labels = np.reshape(df0.Class.to_numpy(), (82,1))
# labels

# %% [markdown]
# <h1><center>Preprocessing</center></h1>

# %%
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler, RobustScaler

scl = StandardScaler().fit(df0.iloc[:, :-1])
stand = scl.transform(df0.iloc[:, :-1])
# stand
df = pd.DataFrame(stand, columns = df0.columns[:-1])
df = pd.concat([df, df0.iloc[:, -1]], axis=1)
df
# Out:
#     1_5-anhydroglucitol  1-monostearin  2_3-dihydroxybutanoic acid NIST  \
# 0             -1.315982      -0.191139                        -0.314134
# 1              0.702901      -0.166243                         1.106687
# 2             -0.811626      -0.195209                        -0.919298
# 3             -0.197261      -0.173185                        -0.235199
# 4             -0.448710      -0.154034                        -0.261511
# ..                  ...            ...                              ...
# 77             0.442585      -0.171749                         1.080375
# 78             0.333923      -0.181803                         0.580457
# 79             0.296543      -0.187548                        -1.261347
# 80            -0.825994      -0.192575                        -1.261347
# 81            -0.172565      -0.171030                         1.685540
#
#     2_4-diaminobutyric acid  2-deoxyerythritol  2-deoxytetronic acid  \
# 0                  0.900240           0.209300             -0.666017
# 1                 -0.833770          -0.534704             -0.188475
# 2                 -1.272795          -0.879151             -1.013320
# 3                 -0.469297          -0.337221             -0.370810
# 4                  0.944419          -0.135146              0.098050
# ..                      ...                ...                   ...
# 77                -0.532803          -0.925077              0.384575
# 78                 0.411514          -0.539297             -0.466318
# 79                -1.394286           0.039373              0.818703
# 80                 0.673825           0.461894             -0.674700
# 81                -0.516236          -0.814854             -0.249253
#
#     2-hydroxybutanoic acid  2-hydroxyglutaric acid  2-hydroxyhippuric acid  \
# 0                 0.727863               -0.138580               -0.400194
# 1                -0.953771               -0.224592               -0.167457
# 2                 1.011716               -0.204851               -0.142067
# 3                 1.930079               -0.161140               -0.163225
# 4                 0.169166               -0.227412               -0.374804
# ..                     ...                     ...                     ...
# 77                0.725645               -0.262663               -0.010889
# 78               -0.665899               -0.244333               -0.302867
# 79               -0.750583               -0.275354               -0.315562
# 80               -0.086412               -0.228822                0.306480
# 81               -0.142545               -0.302144                0.539217
#
#     2-hydroxyvaleric acid  ...  tryptophan  tyrosine  UDP-glucuronic acid  \
# 0               -0.055432  ...    0.523924  1.937765            -0.418593
# 1               -1.295085  ...   -0.898525  0.312181            -0.180562
# 2                0.024593  ...    0.829649 -0.382834            -0.027542
# 3               -1.024456  ...   -1.106561 -0.713525            -0.424260
# 4                0.193372  ...    0.013588 -0.444125             0.003629
# ..                    ...  ...         ...       ...                  ...
# 77              -1.174321  ...    0.980799  0.230176            -0.302411
# 78              -1.328550  ...   -0.029896 -0.827457            -0.313746
# 79              -0.183471  ...    0.944910  0.161091            -0.177728
# 80               0.161362  ...   -1.340508 -1.637365             5.540680
# 81              -0.013237  ...   -0.901056 -0.620628            -0.463932
#
#         urea  uric acid   uridine    valine   xylitol    xylose    Class
# 0   0.378001  -1.016102 -0.694224  1.877948 -0.534297  0.632746  disease
# 1  -0.527748  -1.243045  0.992711 -0.343225 -0.079396 -0.254870  disease
# 2  -1.025622  -0.233142  1.023383 -0.795165 -0.269384 -0.882696  disease
# 3  -0.484832  -0.477333  0.501966 -0.577998 -0.349661 -0.615033  disease
# 4   0.378170   0.762636 -0.847582  1.973716 -0.440641  1.896271  disease
# ..       ...        ...       ...       ...       ...       ...      ...
# 77  0.036487   0.046360 -0.878254  0.141430 -0.272060 -0.398542  control
# 78  1.706386   1.559041 -0.755568  0.646188  0.014261 -0.109230  control
# 79  1.258252   0.298428 -0.295494 -1.364001  0.265794  0.433967  control
# 80  1.202207  -0.008101  0.685996 -0.599248  2.933659 -0.026569  control
# 81 -0.407552   2.021212 -0.203480  0.448019 -0.344309  3.004314  control
#
# [82 rows x 159 columns]

# %% [markdown]
# <h1><center>Shapiro Wilk Test for Normality</center></h1>

# %%
disease = df[(df['Class']=='disease')] #jader disease asa
control = df[(df['Class']=='control')] #jader disese nai

# %%
from scipy import stats
def shapiro_wilk(feature):
    disease_shapiro = stats.shapiro(disease[feature])
    control_shapiro = stats.shapiro(control[feature])
    return feature, disease_shapiro[1], control_shapiro[1] # [1] for p-value, [0]

# %%
shapiro_wilk_result = []
for i in range(1, 158):
    shapiro_wilk_result.append(shapiro_wilk(df.columns[i]))
shapiro_wilk_result_df = pd.DataFrame(shapiro_wilk_result, columns = ['Features', 'Disease', 'Control'])
shapiro_wilk_result_df = shapiro_wilk_result_df[(shapiro_wilk_result_df.Disease>0.05) & (shapiro_wilk_result_df.Control>0.05)]
normal = shapiro_wilk_result_df.Features.to_numpy()
normal
# Out:
# array(['3-hydroxybutanoic acid', 'alanine', 'asparagine', 'azelaic acid',
#        'benzoic acid', 'dodecanol', 'fumaric acid', 'heptadecanoic acid',
#        'hydroxycarbamate NIST', 'hydroxylamine', 'indole-3-lactate',
#        'lysine', 'p-cresol', 'serine', 'threonine', 'tryptophan',
#        'tyrosine', 'urea', 'uric acid'], dtype=object)

# %% [markdown]
# <h>So we can see that, only 19 features has p value > 0.05(normally distributed), which declines the proof of 100% normality of our dataset. Now we proceed to Levene Test for testing Equality of Variance. If dataset was 100% normally distributed, we would use Bartlett’s Test</h>

# %%
non_normal = [i for i in df.columns if i not in normal and i!='Class']
len(non_normal)
# Out:
# 139

# %% [markdown]
# <h1><center>Variance Test</center></h1>

# %% [markdown]
# <h2><center>Bartlett's Test</center></h2>

# %%
def bartlett_test(feature):
    b_test = stats.bartlett(disease[feature], control[feature])
    return feature, b_test[0], b_test[1] # [1] for p-value, [0] for test statistics

# %%
bartlett_result = []
for i in normal:
    bartlett_result.append(bartlett_test(i))
bartlett_result_df = pd.DataFrame(bartlett_result, columns = ['Features', 'test', 'p-Value'])
bartlett_result_df
# Out:
#                   Features      test   p-Value
# 0   3-hydroxybutanoic acid  1.955962  0.161946
# 1                  alanine  0.981100  0.321927
# 2               asparagine  1.573681  0.209673
# 3             azelaic acid  0.134027  0.714292
# 4             benzoic acid  2.315345  0.128103
# 5                dodecanol  1.081147  0.298441
# 6             fumaric acid  1.855480  0.173147
# 7       heptadecanoic acid  0.475677  0.490387
# 8    hydroxycarbamate NIST  0.044703  0.832551
# 9            hydroxylamine  0.146669  0.701739
# 10        indole-3-lactate  0.000006  0.998025
# 11                  lysine  0.213532  0.644013
# 12                p-cresol  0.018331  0.892301
# 13                  serine  1.025887  0.311127
# 14               threonine  0.585678  0.444095
# 15              tryptophan  2.224804  0.135810
# 16                tyrosine  1.275517  0.258734
# 17                    urea  0.019608  0.888638
# 18               uric acid  0.030956  0.860338

# %%
parametric = [bartlett_result_df.loc[i, 'Features']\
                    for i in range(len(bartlett_result)) if bartlett_result_df.loc[i, 'p-Value'] > 0.05]
parametric
# Out:
# ['3-hydroxybutanoic acid',
#  'alanine',
#  'asparagine',
#  'azelaic acid',
#  'benzoic acid',
#  'dodecanol',
#  'fumaric acid',
#  'heptadecanoic acid',
#  'hydroxycarbamate NIST',
#  'hydroxylamine',
#  'indole-3-lactate',
#  'lysine',
#  'p-cresol',
#  'serine',
#  'threonine',
#  'tryptophan',
#  'tyrosine',
#  'urea',
#  'uric acid']

# %% [markdown]
# <h2><center>Levene's Test</center></h2>

# %%
def levene_test(feature):
    l_test = stats.levene(disease[feature], control[feature])
    return feature, l_test[0], l_test[1] # [1] for p-value, [0] for test statistics

# %%
levene_result = []
for i in non_normal:
    levene_result.append(levene_test(i))
levene_result_df = pd.DataFrame(levene_result, columns = ['Features', 'test', 'p-Value'])
levene_result_df
# Out:
#                             Features      test   p-Value
# 0                1_5-anhydroglucitol  0.923284  0.339509
# 1                      1-monostearin  2.614252  0.109844
# 2    2_3-dihydroxybutanoic acid NIST  0.006478  0.936050
# 3            2_4-diaminobutyric acid  0.096940  0.756343
# 4                  2-deoxyerythritol  0.908407  0.343408
# ..                               ...       ...       ...
# 134              UDP-glucuronic acid  1.681392  0.198467
# 135                          uridine  0.032911  0.856501
# 136                           valine  0.354581  0.553212
# 137                          xylitol  0.312940  0.577445
# 138                           xylose  0.229706  0.633049
#
# [139 rows x 3 columns]

# %%
parametric += [levene_result_df.loc[i, 'Features']\
                    for i in range(len(levene_result)) if levene_result_df.loc[i, 'p-Value'] > 0.05]
len(parametric)
138
# Out:
# 138

# %%
non_parametric = [i for i in df.columns if i not in parametric and i!='Class']
len(non_parametric)
# Out:
# 20

# %% [markdown]
# <h>So, we got:</br>Parametric features: 138 which needs Student's t-Test
# </br>NonParametric: 20 which needs Kruskal Wallis t-Test</h>

# %% [markdown]
# <h1><center>Student's t-Test</center><h1>

# %%
t_result = []
for i in parametric:
    t_test = stats.ttest_ind(disease[i], control[i])
    t_result.append([i, t_test[0], t_test[1]])
t_result_df = pd.DataFrame(t_result, columns = ['Features', 'test', 'p-Value'])
t_result_df
# Out:
#                    Features      test   p-Value
# 0    3-hydroxybutanoic acid -2.028900  0.045795
# 1                   alanine -0.894646  0.373660
# 2                asparagine -3.494524  0.000777
# 3              azelaic acid  1.144937  0.255649
# 4              benzoic acid -3.272815  0.001574
# ..                      ...       ...       ...
# 133     UDP-glucuronic acid -1.183851  0.239978
# 134                 uridine -0.013382  0.989356
# 135                  valine -0.845800  0.400187
# 136                 xylitol -0.609977  0.543606
# 137                  xylose  0.424889  0.672058
#
# [138 rows x 3 columns]

# %% [markdown]
# <h1><center>Kruskal Wallis Test</center></h1>

# %%
k_result = []
for i in non_parametric:
    k_test= stats.kruskal(disease[i], control[i])
    k_result.append([i, k_test[0], k_test[1]])
k_result_df = pd.DataFrame(k_result, columns = ['Features', 'test', 'p-Value'])
k_result_df
# Out:
#                      Features       test       p-Value
# 0          3-phosphoglycerate  21.123897  4.305257e-06
# 1         5-methoxytryptamine  21.379296  3.768184e-06
# 2   adenosine-5-monophosphate  37.014868  1.172319e-09
# 3               aspartic acid  19.652367  9.288817e-06
# 4                beta-alanine   1.579168  2.088806e-01
# 5                 citric acid   1.922285  1.656050e-01
# 6     conduritol-beta-epoxide   0.072346  7.879518e-01
# 7             indoxyl sulfate   1.376850  2.406384e-01
# 8              isocitric acid   0.045502  8.310830e-01
# 9                 lactic acid  17.923260  2.299930e-05
# 10                    maltose  14.109041  1.725126e-04
# 11                maltotriose   6.721913  9.523541e-03
# 12            N-methylalanine   6.293177  1.212036e-02
# 13                     phenol  20.650583  5.512039e-06
# 14        phosphoethanolamine  10.064033  1.511919e-03
# 15              pyrophosphate  28.288926  1.044920e-07
# 16               pyruvic acid  13.182536  2.825701e-04
# 17              shikimic acid   0.166521  6.832223e-01
# 18                    taurine  24.617982  6.989644e-07
# 19              threonic acid   2.559283  1.096483e-01

# %%
result_df = pd.concat([t_result_df, k_result_df], axis=0, ignore_index=True)
result_df
# Out:
#                    Features       test       p-Value
# 0    3-hydroxybutanoic acid  -2.028900  4.579484e-02
# 1                   alanine  -0.894646  3.736602e-01
# 2                asparagine  -3.494524  7.772173e-04
# 3              azelaic acid   1.144937  2.556490e-01
# 4              benzoic acid  -3.272815  1.573528e-03
# ..                      ...        ...           ...
# 153           pyrophosphate  28.288926  1.044920e-07
# 154            pyruvic acid  13.182536  2.825701e-04
# 155           shikimic acid   0.166521  6.832223e-01
# 156                 taurine  24.617982  6.989644e-07
# 157           threonic acid   2.559283  1.096483e-01
#
# [158 rows x 3 columns]

# %%
metabolics = result_df[(result_df['p-Value'] < 0.015)].loc[:, 'Features']
metabolics = metabolics.to_numpy()
len(metabolics)
# metabolics
# Out:
# 26

# %%
metabolites = result_df[(result_df['p-Value'] < 0.015)]
latex_metabolites = metabolites.loc[:, ['Features', 'p-Value']]
latex_metabolites.to_latex('output.tex')

# %%
r_metabolites = result_df[(result_df['p-Value'] >= 0.015)]
latex_metabolites = r_metabolites.loc[:, ['Features', 'p-Value']]
latex_metabolites.to_latex('output_removed.tex')
latex_metabolites.to_csv('output_removed.csv', index=False)

# %%
latex_metabolites
# Out:
#                     Features   p-Value
# 0     3-hydroxybutanoic acid  0.045795
# 1                    alanine  0.373660
# 3               azelaic acid  0.255649
# 5                  dodecanol  0.308227
# 6               fumaric acid  0.446523
# ..                       ...       ...
# 144  conduritol-beta-epoxide  0.787952
# 145          indoxyl sulfate  0.240638
# 146           isocitric acid  0.831083
# 155            shikimic acid  0.683222
# 157            threonic acid  0.109648
#
# [132 rows x 2 columns]

# %% [markdown]
# <h>Now we keep the data of these metabolics only, from main dataset.</h>

# %%
final_df = df.loc[:, metabolics]
final_df = pd.concat([final_df, df.loc[:, 'Class']], axis=1)
final_df.to_csv('plasma(Specific Metabolics)_final2.csv')
final_df
# Out:
#     asparagine  benzoic acid  tryptophan  uric acid  5-hydroxynorvaline NIST  \
# 0    -0.384776     -1.305536    0.523924  -1.016102                -0.853596
# 1     0.947427     -0.462690   -0.898525  -1.243045                -0.821435
# 2     0.692741     -0.487775    0.829649  -0.233142                -0.351887
# 3     0.349894      1.682051   -1.106561  -0.477333                -0.744249
# 4     0.297651     -1.197672    0.013588   0.762636                 0.992437
# ..         ...           ...         ...        ...                      ...
# 77    0.771106     -0.628249    0.980799   0.046360                -0.287565
# 78   -0.427224     -1.057197   -0.029896   1.559041                -0.197515
# 79   -0.103969      1.496424    0.944910   0.298428                -0.081736
# 80   -1.220668      0.896900   -1.340508  -0.008101                -0.795707
# 81   -1.201077      2.201304   -0.901056   2.021212                -0.454802
#
#     alpha-ketoglutarate  citrulline  glutamine  hypoxanthine  malic acid  ...  \
# 0              0.512135   -0.326638  -0.190839      0.415434    0.756656  ...
# 1             -0.392098    0.687196   1.044991      1.371994    0.094793  ...
# 2              0.353377   -0.563638   0.355438     -0.305743    0.064009  ...
# 3             -0.751031   -0.994847   1.152050      1.912876   -0.413148  ...
# 4             -0.143607    0.766196  -0.305898      0.245156    0.756656  ...
# ..                  ...         ...        ...           ...         ...  ...
# 77            -0.295463    0.078237   1.063280     -0.656314   -0.967265  ...
# 78            -0.640590   -0.408930  -0.134892      5.193226   -0.674814  ...
# 79             0.781335    0.914321   1.465637     -0.666331    1.218420  ...
# 80            -0.136704   -1.169305  -1.386388     -0.440963   -0.089913  ...
# 81            -1.027133   -0.978388  -1.320048     -0.891698   -0.228442  ...
#
#     lactic acid   maltose  maltotriose  N-methylalanine    phenol  \
# 0     -0.042836 -0.338804    -1.207098        -0.095912 -0.099283
# 1      0.154308 -0.294908    -0.127933        -1.188920  0.216627
# 2      1.064361  0.235490     0.675167        -0.710083  0.984663
# 3      0.526588 -0.192487    -0.378901         1.832288  0.687592
# 4     -0.325137 -0.009591     1.428073         0.911157 -0.273178
# ..          ...       ...          ...              ...       ...
# 77    -0.722605 -0.353435    -0.378901         0.753645 -0.678933
# 78     0.644590 -0.188829    -0.604773         0.508431  0.791929
# 79    -0.532977 -0.349777     0.047745        -0.944209 -0.444175
# 80    -0.460003 -0.499752    -0.830645         0.695933 -0.180434
# 81    -0.410743 -0.013249    -0.730257        -0.792241 -0.470259
#
#     phosphoethanolamine  pyrophosphate  pyruvic acid   taurine    Class
# 0              0.034358      -0.273237      1.375625  0.414720  disease
# 1             -0.830514      -0.405431      0.290328 -0.157190  disease
# 2              0.021254       0.950369     -0.192526  0.829635  disease
# 3             -0.188412      -0.592977     -0.663066  1.246152  disease
# 4              0.322649       0.521378     -0.094013  0.075899  disease
# ..                  ...            ...           ...       ...      ...
# 77            -0.450494      -0.956782     -0.116747 -0.373459  control
# 78            -0.424286      -0.221161     -0.514587 -0.233285  control
# 79            -0.240828      -0.666904     -0.357819 -0.544071  control
# 80            -0.437390      -0.918180     -0.103486 -1.054304  control
# 81            -0.581535      -0.955689     -1.050013 -0.620966  control
#
# [82 rows x 27 columns]

# %% [markdown]
# <h1><center>Visualization</center></h1>

# %%
# Data set
import seaborn as sns
final_df1 = final_df.copy()
Class = final_df.pop("Class")
# final_df = final_df.set_index('Metabolics')

lut = dict(zip(Class.unique(), "grb"))
row_colors = Class.map(lut)
df_colors = pd.DataFrame(data={'DISEASE': row_colors[row_colors == 'r'], 'CONTROL': row_colors[row_colors == 'g']}) 
# Default plot
g = sns.clustermap(final_df, cmap='RdBu', row_colors=df_colors, z_score=1)      #z_score->standardize; standard_cale->normalize
g.fig.subplots_adjust(right=0.9)
g.ax_cbar.set_position((0.7, .2, .03, .4), 'horizontal')
plt.setp(g.ax_heatmap.get_yticklabels(), rotation=0)
# Show the graph
plt.savefig('clustermap_plasma.JPG')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from yellowbrick.model_selection import FeatureImportances

# Load the classification data set
X = final_df1.drop('Class', axis=1)
y = final_df1['Class'].copy()
y = y.map({"control": 1, "disease": 0})

model = RandomForestClassifier(n_estimators=29)
viz = FeatureImportances(model)
viz.fit(X, y)
viz.show()
# Out:
# <Axes: title={'center': 'Feature Importances of 26 Features using RandomForestClassifier'}, xlabel='relative importance'>
